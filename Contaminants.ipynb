# %% [markdown]
# <a href="https://colab.research.google.com/github/Alvaro-Murua/Growa-Inniative-/blob/main/Contaminants.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Crear un diccionario con los datos
data = {
    "Año": [
        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
        2020, 2021, 2022, 2023, 2024
    ],
    "Emisiones PM2.5 (kg)": [
        np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
        np.nan, np.nan, np.nan, np.nan, np.nan, 1564990.40, 1846531.10,
        1054848.80, 1381154.80, 1390215.60, 816403.25, 659189.90,
        1889496.00, 1385045.50, 1248556.50, 2853142.20, 3148447.80,
        2621041.20, 804039.10, 2444020.80, 1255252.50, 1155101.20,
        206002.66, 2194094.50, 1184630.40, 10711929.00, 4942122.00
    ],
    "Metano(ppb)": [
        1825.0, 1834.0, 1838.0, 1836.0, 1849.0, 1852.0, 1840.0, 1854.0,
        1887.0, 1858.0, 1859.0, 1863.0, 1871.0, 1883.0, 1872.0, 1885.0,
        1873.0, 1890.0, 1892.0, 1891.0, 1900.0, 1909.0, 1914.0, 1912.0,
        1929.0, 1947.0, 1952.0, 1949.0, 1962.0, 1969.0, 1995.0, 2011.0,
        2016.0, np.nan, np.nan
    ],

    "NOₓ (t)": [
        4170.0, 4794.0, 5820.0, 5312.0, 4522.0, 4914.0, 5072.0, 5048.0,
        4422.0, 4624.0, 4488.0, 4100.0, 3900.0, 4208.0, 4250.0, 4236.0,
        3924.0, 4952.0, 5028.0, 5346.0, 5622.0, 6756.0, 6634.0, 6138.0,
        5770.0, 5396.0, 5770.0, 5596.0, 5608.0, 5730.0, 5274.0, 5368.0,
        5730.0, np.nan, np.nan
    ],
    "COV (t)": [
        103656.0, 103710.0, 105407.0, 105214.0, 107580.0, 111583.0,
        114609.0, 115309.0, 115724.0, 116040.0, 116955.0, 119948.0,
        121090.0, 120643.0, 124574.0, 125702.0, 123068.0, 120951.0,
        119045.0, 116341.0, 115395.0, 114311.0, 114932.0, 116279.0,
        115423.0, 114200.0, 114791.0, 115078.0, 115812.0, 115589.0,
        115349.0, 115854.0, 115105.0, np.nan, np.nan
    ],
    "Cadmio (kg)": [
        102.0, 116.0, 164.0, 132.0, 120.0, 136.0, 130.0, 134.0, 106.0,
        114.0, 108.0, 106.0, 108.0, 102.0, 108.0, 128.0, 120.0, 142.0,
        138.0, 130.0, 142.0, 162.0, 174.0, 158.0, 148.0, 148.0, 164.0,
        164.0, 160.0, 168.0, 150.0, 152.0, 162.0, np.nan, np.nan
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Mostrar el DataFrame
print(df)
# Out:
#      Año  Emisiones PM2.5 (kg)  Diciembre - Canadá (ppb)  SO₂ (t)  NOₓ (t)  \
# 0   1990                   NaN                    1825.0      NaN   4170.0
# 1   1991                   NaN                    1834.0      NaN   4794.0
# 2   1992                   NaN                    1838.0      NaN   5820.0
# 3   1993                   NaN                    1836.0      NaN   5312.0
# 4   1994                   NaN                    1849.0      NaN   4522.0
# 5   1995                   NaN                    1852.0      NaN   4914.0
# 6   1996                   NaN                    1840.0   4182.0   5072.0
# 7   1997                   NaN                    1854.0   7600.0   5048.0
# 8   1998                   NaN                    1887.0   6620.0   4422.0
# 9   1999                   NaN                    1858.0   6970.0   4624.0
# 10  2000                   NaN                    1859.0   6876.0   4488.0
# ...

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# Crear un diccionario con los datos
data = {
    "Año": [
        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
        2020, 2021, 2022, 2023, 2024
    ],
    "Emisiones PM2.5 (kg)": [
        np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
        np.nan, np.nan, np.nan, np.nan, np.nan, 1564990.40, 1846531.10,
        1054848.80, 1381154.80, 1390215.60, 816403.25, 659189.90,
        1889496.00, 1385045.50, 1248556.50, 2853142.20, 3148447.80,
        2621041.20, 804039.10, 2444020.80, 1255252.50, 1155101.20,
        206002.66, 2194094.50, 1184630.40, 10711929.00, 4942122.00
    ],
    "Diciembre - Canadá (ppb)": [
        1825.0, 1834.0, 1838.0, 1836.0, 1849.0, 1852.0, 1840.0, 1854.0,
        1887.0, 1858.0, 1859.0, 1863.0, 1871.0, 1883.0, 1872.0, 1885.0,
        1873.0, 1890.0, 1892.0, 1891.0, 1900.0, 1909.0, 1914.0, 1912.0,
        1929.0, 1947.0, 1952.0, 1949.0, 1962.0, 1969.0, 1995.0, 2011.0,
        2016.0, np.nan, np.nan
    ],
    "SO₂ (t)": [
        np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 4182.0, 7600.0,
        6620.0, 6970.0, 6876.0, 9124.0, 6854.0, 0.0, 0.0, 0.0,
        730.0, 606.0, 474.0, 440.0, 386.0, 326.0, 342.0, np.nan,
        np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
        np.nan, np.nan, np.nan
    ],
    "NOₓ (t)": [
        4170.0, 4794.0, 5820.0, 5312.0, 4522.0, 4914.0, 5072.0, 5048.0,
        4422.0, 4624.0, 4488.0, 4100.0, 3900.0, 4208.0, 4250.0, 4236.0,
        3924.0, 4952.0, 5028.0, 5346.0, 5622.0, 6756.0, 6634.0, 6138.0,
        5770.0, 5396.0, 5770.0, 5596.0, 5608.0, 5730.0, 5274.0, 5368.0,
        5730.0, np.nan, np.nan
    ],
    "COV (t)": [
        103656.0, 103710.0, 105407.0, 105214.0, 107580.0, 111583.0,
        114609.0, 115309.0, 115724.0, 116040.0, 116955.0, 119948.0,
        121090.0, 120643.0, 124574.0, 125702.0, 123068.0, 120951.0,
        119045.0, 116341.0, 115395.0, 114311.0, 114932.0, 116279.0,
        115423.0, 114200.0, 114791.0, 115078.0, 115812.0, 115589.0,
        115349.0, 115854.0, 115105.0, np.nan, np.nan
    ],
    "Cadmio (kg)": [
        102.0, 116.0, 164.0, 132.0, 120.0, 136.0, 130.0, 134.0, 106.0,
        114.0, 108.0, 106.0, 108.0, 102.0, 108.0, 128.0, 120.0, 142.0,
        138.0, 130.0, 142.0, 162.0, 174.0, 158.0, 148.0, 148.0, 164.0,
        164.0, 160.0, 168.0, 150.0, 152.0, 162.0, np.nan, np.nan
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Crear una tabla interactiva con Plotly
fig = px.scatter(df, x="Año", y="Emisiones PM2.5 (kg)",
                 title="Emisiones PM2.5 por Año",
                 labels={"Emisiones PM2.5 (kg)": "Emisiones PM2.5 (kg)", "Año": "Año"},
                 hover_data=["Diciembre - Canadá (ppb)", "SO₂ (t)", "NOₓ (t)", "COV (t)", "Cadmio (kg)"])

# Mostrar la figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# Crear un diccionario con los datos
data = {
    "Año": [
        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
        2020, 2021, 2022, 2023, 2024
    ],
    "Emisiones PM2.5 (kg)": [
        np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
        np.nan, np.nan, np.nan, np.nan, np.nan, 1564990.40, 1846531.10,
        1054848.80, 1381154.80, 1390215.60, 816403.25, 659189.90,
        1889496.00, 1385045.50, 1248556.50, 2853142.20, 3148447.80,
        2621041.20, 804039.10, 2444020.80, 1255252.50, 1155101.20,
        206002.66, 2194094.50, 1184630.40, 10711929.00, 4942122.00
    ],
    "Diciembre - Canadá (ppb)": [
        1825.0, 1834.0, 1838.0, 1836.0, 1849.0, 1852.0, 1840.0, 1854.0,
        1887.0, 1858.0, 1859.0, 1863.0, 1871.0, 1883.0, 1872.0, 1885.0,
        1873.0, 1890.0, 1892.0, 1891.0, 1900.0, 1909.0, 1914.0, 1912.0,
        1929.0, 1947.0, 1952.0, 1949.0, 1962.0, 1969.0, 1995.0, 2011.0,
        2016.0, np.nan, np.nan
    ],
    "SO₂ (t)": [
        np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, 4182.0, 7600.0,
        6620.0, 6970.0, 6876.0, 9124.0, 6854.0, 0.0, 0.0, 0.0,
        730.0, 606.0, 474.0, 440.0, 386.0, 326.0, 342.0, np.nan,
        np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan,
        np.nan, np.nan, np.nan
    ],
    "NOₓ (t)": [
        4170.0, 4794.0, 5820.0, 5312.0, 4522.0, 4914.0, 5072.0, 5048.0,
        4422.0, 4624.0, 4488.0, 4100.0, 3900.0, 4208.0, 4250.0, 4236.0,
        3924.0, 4952.0, 5028.0, 5346.0, 5622.0, 6756.0, 6634.0, 6138.0,
        5770.0, 5396.0, 5770.0, 5596.0, 5608.0, 5730.0, 5274.0, 5368.0,
        5730.0, np.nan, np.nan
    ],
    "COV (t)": [
        103656.0, 103710.0, 105407.0, 105214.0, 107580.0, 111583.0,
        114609.0, 115309.0, 115724.0, 116040.0, 116955.0, 119948.0,
        121090.0, 120643.0, 124574.0, 125702.0, 123068.0, 120951.0,
        119045.0, 116341.0, 115395.0, 114311.0, 114932.0, 116279.0,
        115423.0, 114200.0, 114791.0, 115078.0, 115812.0, 115589.0,
        115349.0, 115854.0, 115105.0, np.nan, np.nan
    ],
    "Cadmio (kg)": [
        102.0, 116.0, 164.0, 132.0, 120.0, 136.0, 130.0, 134.0, 106.0,
        114.0, 108.0, 106.0, 108.0, 102.0, 108.0, 128.0, 120.0, 142.0,
        138.0, 130.0, 142.0, 162.0, 174.0, 158.0, 148.0, 148.0, 164.0,
        164.0, 160.0, 168.0, 150.0, 152.0, 162.0, np.nan, np.nan
    ]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Función para crear gráficos
def create_graph(y_data, title, y_label):
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df["Año"], y=y_data, mode='lines+markers', name=y_label, line=dict(width=2)))
    fig.update_layout(title=title, xaxis_title='Año', yaxis_title=y_label,
                      template='plotly_white', height=400, margin=dict(l=40, r=40, t=40, b=40))
    return fig

# Crear gráficos para cada contaminante
fig_pm25 = create_graph(df["Emisiones PM2.5 (kg)"], "Emisiones de PM2.5 por Año", "Emisiones PM2.5 (kg)")
fig_so2 = create_graph(df["SO₂ (t)"], "Emisiones de SO₂ por Año", "Emisiones SO₂ (t)")
fig_nox = create_graph(df["NOₓ (t)"], "Emisiones de NOₓ por Año", "Emisiones NOₓ (t)")
fig_cov = create_graph(df["COV (t)"], "Emisiones de COV por Año", "Emisiones COV (t)")
fig_cadmio = create_graph(df["Cadmio (kg)"], "Emisiones de Cadmio por Año", "Emisiones Cadmio (kg)")

# Mostrar los gráficos
fig_pm25.show()
fig_so2.show()
fig_nox.show()
fig_cov.show()
fig_cadmio.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
