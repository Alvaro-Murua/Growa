# %% [markdown]
# <a href="https://colab.research.google.com/github/Alvaro-Murua/Growa/blob/main/Contaminantes_Agricolas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from IPython.display import display

# Updated data
agriculture_emissions_data = {
    'Source': ['Agriculture', 'Agriculture', 'Agriculture', 'Agriculture', 'Agriculture', 'Agriculture', 'Agriculture', 'Agriculture'],
    'Sector': [None, 'Animal Production', 'Crop Production', 'Crop Production', 'Crop Production', 'Crop Production', 'Crop Production', 'Agricultural Fuel Combustion'],
    'SubSector': [None, None, None, 'Harvesting', 'Inorganic Fertilizer Application', 'Tillage Practices', 'Wind Erosion', None],
    '2006': [1670500, 11023, 1659302, 122976, 5247, 344724, 1186355, 174],
    '2007': [1629623, 10588, 1618777, 121088, 5247, 326142, 1166300, 258],
    '2008': [1587194, 10333, 1576492, 119152, 5247, 307601, 1144491, 369],
    '2009': [1545802, 9908, 1535378, 117282, 5377, 289122, 1123597, 516],
    '2010': [1506072, 9726, 1495847, 115379, 6236, 270557, 1103675, 500],
    '2011': [1465921, 9674, 1455675, 113282, 6236, 251568, 1084589, 571],
    '2012': [1487224, 9777, 1476934, 113991, 6236, 247443, 1109264, 513],
    '2013': [1507720, 9793, 1497459, 114519, 6236, 242841, 1133864, 467],
    '2014': [1528529, 9648, 1518452, 115111, 6236, 238248, 1158857, 429],
    '2015': [1550040, 9806, 1539858, 115746, 6236, 233669, 1184206, 376],
    '2016': [1571555, 9995, 1561180, 116261, 6236, 228677, 1210006, 379],
    '2017': [1556469, 10005, 1546101, 117406, 6236, 224507, 1197952, 363],
    '2018': [1541365, 9996, 1531042, 118545, 6236, 220309, 1185953, 326],
}

# Create a DataFrame
df_agriculture_emissions = pd.DataFrame(agriculture_emissions_data)

# Display the table
display(df_agriculture_emissions)
# Out:
#         Source                        Sector  \
# 0  Agriculture                          None
# 1  Agriculture             Animal Production
# 2  Agriculture               Crop Production
# 3  Agriculture               Crop Production
# 4  Agriculture               Crop Production
# 5  Agriculture               Crop Production
# 6  Agriculture               Crop Production
# 7  Agriculture  Agricultural Fuel Combustion
#
#                           SubSector     2006     2007     2008     2009  \
# 0                              None  1670500  1629623  1587194  1545802
# 1                              None    11023    10588    10333     9908
# 2                              None  1659302  1618777  1576492  1535378
# 3                        Harvesting   122976   121088   119152   117282
# 4  Inorganic Fertilizer Application     5247     5247     5247     5377
# 5                 Tillage Practices   344724   326142   307601   289122
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Updated data
agriculture_emissions_data = {
    'Source': ['Agriculture', 'Agriculture', 'Agriculture', 'Agriculture', 'Agriculture', 'Agriculture', 'Agriculture', 'Agriculture'],
    'Sector': [None, 'Animal Production', 'Crop Production', 'Crop Production', 'Crop Production', 'Crop Production', 'Crop Production', 'Agricultural Fuel Combustion'],
    'SubSector': [None, None, None, 'Harvesting', 'Inorganic Fertilizer Application', 'Tillage Practices', 'Wind Erosion', None],
    '2006': [1670500, 11023, 1659302, 122976, 5247, 344724, 1186355, 174],
    '2007': [1629623, 10588, 1618777, 121088, 5247, 326142, 1166300, 258],
    '2008': [1587194, 10333, 1576492, 119152, 5247, 307601, 1144491, 369],
    '2009': [1545802, 9908, 1535378, 117282, 5377, 289122, 1123597, 516],
    '2010': [1506072, 9726, 1495847, 115379, 6236, 270557, 1103675, 500],
    '2011': [1465921, 9674, 1455675, 113282, 6236, 251568, 1084589, 571],
    '2012': [1487224, 9777, 1476934, 113991, 6236, 247443, 1109264, 513],
    '2013': [1507720, 9793, 1497459, 114519, 6236, 242841, 1133864, 467],
    '2014': [1528529, 9648, 1518452, 115111, 6236, 238248, 1158857, 429],
    '2015': [1550040, 9806, 1539858, 115746, 6236, 233669, 1184206, 376],
    '2016': [1571555, 9995, 1561180, 116261, 6236, 228677, 1210006, 379],
    '2017': [1556469, 10005, 1546101, 117406, 6236, 224507, 1197952, 363],
    '2018': [1541365, 9996, 1531042, 118545, 6236, 220309, 1185953, 326],
}

# Create a DataFrame
df_agriculture_emissions = pd.DataFrame(agriculture_emissions_data)

# Set the index to years for easier plotting
years = df_agriculture_emissions.columns[3:].astype(int)
total_emissions = df_agriculture_emissions.iloc[:, 3:].sum(axis=0)

# 1. Line Plot of Total Emissions Over the Years
plt.figure(figsize=(12, 6))
plt.plot(years, total_emissions, marker='o')
plt.title('Total Agricultural Emissions Over the Years')
plt.xlabel('Year')
plt.ylabel('Total Emissions (g CO2 equivalent)')
plt.grid()
plt.xticks(years)
plt.show()

# 2. Bar Plot of Emissions by Sector for 2018
emissions_2018 = df_agriculture_emissions[df_agriculture_emissions['Sector'].notnull()]
emissions_2018 = emissions_2018[['Sector', '2018']].copy()
emissions_2018['2018'] = emissions_2018['2018'].astype(int)

plt.figure(figsize=(10, 6))
sns.barplot(x='Sector', y='2018', data=emissions_2018)
plt.title('Agricultural Emissions by Sector in 2018')
plt.xlabel('Sector')
plt.ylabel('Emissions (g CO2 equivalent)')
plt.xticks(rotation=45)
plt.show()

# %%
Emission trends for Sulphur Dioxide (tonne), Canada

https://pollution-waste.canada.ca/air-emission-inventory/?GoCTemplateCulture=en-CA

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# SO₂ emission data (in tons)
so2_emission_data = {
    'Source': ['Agriculture', 'Agriculture', 'Agriculture', 'Agriculture'],
    'Sector': [None, 'Animal Production', 'Crop Production', 'Agricultural Fuel Combustion'],
    'SubSector': [None, None, None, None],
    '2006': [2091, None, None, 2091],
    '2007': [3800, None, None, 3800],
    '2008': [3310, None, None, 3310],
    '2009': [3485, None, None, 3485],
    '2010': [3438, None, None, 3438],
    '2011': [4562, None, None, 4562],
    '2012': [3427, None, None, 3427],
    '2013': [None, None, None, None],
    '2014': [None, None, None, None],
    '2015': [None, None, None, None],
    '2016': [365, None, None, 365],
    '2017': [303, None, None, 303],
    '2018': [237, None, None, 237],
    '2019': [220, None, None, 220],
    '2020': [193, None, None, 193],
    '2021': [163, None, None, 163],
    '2022': [171, None, None, 171],
}

# Create a DataFrame
df_so2_emissions = pd.DataFrame(so2_emission_data)

# Display the table
display(df_so2_emissions)

# Set the index to years for easier plotting
years = df_so2_emissions.columns[3:].astype(int)
emissions = df_so2_emissions.iloc[:, 3:].fillna(0).sum(axis=0)

# %%
Emission trends for Nitrogen Oxides (tonne), Canada !

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# NOx emission data (in tons)
nox_emission_data = {
    'Source': ['Agriculture', 'Agriculture', 'Agriculture', 'Agriculture'],
    'Sector': [None, 'Animal Production', 'Crop Production', 'Agricultural Fuel Combustion'],
    'SubSector': [None, None, None, None],
    '1990': [2085, None, None, 2085],
    '1991': [2397, None, None, 2397],
    '1992': [2910, None, None, 2910],
    '1993': [2656, None, None, 2656],
    '1994': [2261, None, None, 2261],
    '1995': [2457, None, None, 2457],
    '1996': [2536, None, None, 2536],
    '1997': [2524, None, None, 2524],
    '1998': [2211, None, None, 2211],
    '1999': [2312, None, None, 2312],
    '2000': [2244, None, None, 2244],
    '2001': [2050, None, None, 2050],
    '2002': [1950, None, None, 1950],
    '2003': [2104, None, None, 2104],
    '2004': [2125, None, None, 2125],
    '2005': [2118, None, None, 2118],
    '2006': [1962, None, None, 1962],
    '2007': [2476, None, None, 2476],
    '2008': [2514, None, None, 2514],
    '2009': [2673, None, None, 2673],
    '2010': [2811, None, None, 2811],
    '2011': [3378, None, None, 3378],
    '2012': [3317, None, None, 3317],
    '2013': [3069, None, None, 3069],
    '2014': [2885, None, None, 2885],
    '2015': [2698, None, None, 2698],
    '2016': [2885, None, None, 2885],
    '2017': [2798, None, None, 2798],
    '2018': [2804, None, None, 2804],
    '2019': [2865, None, None, 2865],
    '2020': [2637, None, None, 2637],
    '2021': [2684, None, None, 2684],
    '2022': [2865, None, None, 2865],
}

# Create a DataFrame
df_nox_emissions = pd.DataFrame(nox_emission_data)

# Display the table
display(df_nox_emissions)

# Set the index to years for easier plotting
years = df_nox_emissions.columns[3:].astype(int)
emissions = df_nox_emissions.iloc[:, 3:].fillna(0).sum(axis=0)

# Plotting NOx emissions over the years
plt.figure(figsize=(12, 6))
plt.plot(years, emissions, marker='o', color='g')
plt.title('NOx Emissions from Agriculture Over the Years')
plt.xlabel('Year')
plt.ylabel('NOx Emissions (tons)')
plt.xticks(years, rotation=45)
plt.grid()
plt.show()
# Out:
#         Source                        Sector SubSector    1990    1991  \
# 0  Agriculture                          None      None  2085.0  2397.0
# 1  Agriculture             Animal Production      None     NaN     NaN
# 2  Agriculture               Crop Production      None     NaN     NaN
# 3  Agriculture  Agricultural Fuel Combustion      None  2085.0  2397.0
#
#      1992    1993    1994    1995    1996  ...    2013    2014    2015  \
# 0  2910.0  2656.0  2261.0  2457.0  2536.0  ...  3069.0  2885.0  2698.0
# 1     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 3  2910.0  2656.0  2261.0  2457.0  2536.0  ...  3069.0  2885.0  2698.0
#
#      2016    2017    2018    2019    2020    2021    2022
# 0  2885.0  2798.0  2804.0  2865.0  2637.0  2684.0  2865.0
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# Setting to show all columns
pd.set_option('display.max_columns', None)

# NOx emission data (in tons)
nox_emission_data = {
    'Source': ['Agriculture', 'Agriculture', 'Agriculture', 'Agriculture'],
    'Sector': [None, 'Animal Production', 'Crop Production', 'Agricultural Fuel Combustion'],
    'SubSector': [None, None, None, None],
    '1990': [2085, None, None, 2085],
    '1991': [2397, None, None, 2397],
    '1992': [2910, None, None, 2910],
    '1993': [2656, None, None, 2656],
    '1994': [2261, None, None, 2261],
    '1995': [2457, None, None, 2457],
    '1996': [2536, None, None, 2536],
    '1997': [2524, None, None, 2524],
    '1998': [2211, None, None, 2211],
    '1999': [2312, None, None, 2312],
    '2000': [2244, None, None, 2244],
    '2001': [2050, None, None, 2050],
    '2002': [1950, None, None, 1950],
    '2003': [2104, None, None, 2104],
    '2004': [2125, None, None, 2125],
    '2005': [2118, None, None, 2118],
    '2006': [1962, None, None, 1962],
    '2007': [2476, None, None, 2476],
    '2008': [2514, None, None, 2514],
    '2009': [2673, None, None, 2673],
    '2010': [2811, None, None, 2811],
    '2011': [3378, None, None, 3378],
    '2012': [3317, None, None, 3317],
    '2013': [3069, None, None, 3069],
    '2014': [2885, None, None, 2885],
    '2015': [2698, None, None, 2698],
    '2016': [2885, None, None, 2885],
    '2017': [2798, None, None, 2798],
    '2018': [2804, None, None, 2804],
    '2019': [2865, None, None, 2865],
    '2020': [2637, None, None, 2637],
    '2021': [2684, None, None, 2684],
    '2022': [2865, None, None, 2865],
}

# Create a DataFrame
df_nox_emissions = pd.DataFrame(nox_emission_data)

# Display the table
display(df_nox_emissions)

# Set the index to years for easier plotting
years = df_nox_emissions.columns[3:].astype(int)
emissions = df_nox_emissions.iloc[:, 3:].fillna(0).sum(axis=0)

# Plotting NOx emissions over the years
plt.figure(figsize=(12, 6))
plt.plot(years, emissions, marker='o', color='r')
plt.title('NOx Emissions from Agriculture Over the Years')
plt.xlabel('Year')
plt.ylabel('NOx Emissions (tons)')
plt.xticks(years, rotation=45)
plt.grid()
plt.show()
# Out:
#         Source                        Sector SubSector    1990    1991  \
# 0  Agriculture                          None      None  2085.0  2397.0
# 1  Agriculture             Animal Production      None     NaN     NaN
# 2  Agriculture               Crop Production      None     NaN     NaN
# 3  Agriculture  Agricultural Fuel Combustion      None  2085.0  2397.0
#
#      1992    1993    1994    1995    1996    1997    1998    1999    2000  \
# 0  2910.0  2656.0  2261.0  2457.0  2536.0  2524.0  2211.0  2312.0  2244.0
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3  2910.0  2656.0  2261.0  2457.0  2536.0  2524.0  2211.0  2312.0  2244.0
#
#      2001    2002    2003    2004    2005    2006    2007    2008    2009  \
# 0  2050.0  1950.0  2104.0  2125.0  2118.0  1962.0  2476.0  2514.0  2673.0
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# VOC emission data (in tons)
voc_emission_data = {
    'Source': ['Agriculture', 'Agriculture', 'Agriculture', 'Agriculture'],
    'Sector': [None, 'Animal Production', 'Crop Production', 'Agricultural Fuel Combustion'],
    'SubSector': [None, None, None, None],
    '1990': [103575, None, None, 81],
    '1991': [103623, None, None, 87],
    '1992': [105303, None, None, 104],
    '1993': [105108, None, None, 106],
    '1994': [107494, None, None, 86],
    '1995': [111493, None, None, 90],
    '1996': [114513, None, None, 96],
    '1997': [115213, None, None, 96],
    '1998': [115640, None, None, 84],
    '1999': [115953, None, None, 87],
    '2000': [116864, None, None, 91],
    '2001': [119865, None, None, 83],
    '2002': [121010, None, None, 80],
    '2003': [120561, None, None, 82],
    '2004': [124493, None, None, 81],
    '2005': [125620, None, None, 82],
    '2006': [122989, None, None, 79],
    '2007': [120857, None, None, 94],
    '2008': [118926, None, None, 119],
    '2009': [116192, None, None, 149],
    '2010': [115243, None, None, 152],
    '2011': [114136, None, None, 175],
    '2012': [114756, None, None, 176],
    '2013': [116109, None, None, 170],
    '2014': [115255, None, None, 168],
    '2015': [114039, None, None, 161],
    '2016': [114622, None, None, 169],
    '2017': [114915, None, None, 163],
    '2018': [115653, None, None, 159],
    '2019': [115428, None, None, 161],
    '2020': [115202, None, None, 147],
    '2021': [115705, None, None, 149],
    '2022': [114947, None, None, 158],
}

# Create a DataFrame
df_voc_emissions = pd.DataFrame(voc_emission_data)

# Display the table
display(df_voc_emissions)

# Set the index to years for easier plotting
years = df_voc_emissions.columns[3:].astype(int)
emissions = df_voc_emissions.iloc[:, 3:].fillna(0).sum(axis=0)

# Plotting VOC emissions over the years
plt.figure(figsize=(12, 6))
plt.plot(years, emissions, marker='o', color='b')
plt.title('VOC Emissions from Agriculture Over the Years')
plt.xlabel('Year')
plt.ylabel('VOC Emissions (tons)')
plt.xticks(years, rotation=45)
plt.grid()
plt.show()
# Out:
#         Source                        Sector SubSector      1990      1991  \
# 0  Agriculture                          None      None  103575.0  103623.0
# 1  Agriculture             Animal Production      None       NaN       NaN
# 2  Agriculture               Crop Production      None       NaN       NaN
# 3  Agriculture  Agricultural Fuel Combustion      None      81.0      87.0
#
#        1992      1993      1994      1995      1996      1997      1998  \
# 0  105303.0  105108.0  107494.0  111493.0  114513.0  115213.0  115640.0
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3     104.0     106.0      86.0      90.0      96.0      96.0      84.0
#
#        1999      2000      2001      2002      2003      2004      2005  \
# 0  115953.0  116864.0  119865.0  121010.0  120561.0  124493.0  125620.0
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# Cadmium emission data (inorganic/respirable/soluble) in kg
cadmium_emission_data = {
    'Source': ['Agriculture', 'Agriculture', 'Agriculture', 'Agriculture'],
    'Sector': [None, 'Animal Production', 'Crop Production', 'Agricultural Fuel Combustion'],
    'SubSector': [None, None, None, None],
    '1990': [51, None, None, 51],
    '1991': [58, None, None, 58],
    '1992': [82, None, None, 82],
    '1993': [66, None, None, 66],
    '1994': [60, None, None, 60],
    '1995': [68, None, None, 68],
    '1996': [65, None, None, 65],
    '1997': [67, None, None, 67],
    '1998': [53, None, None, 53],
    '1999': [57, None, None, 57],
    '2000': [54, None, None, 54],
    '2001': [53, None, None, 53],
    '2002': [54, None, None, 54],
    '2003': [51, None, None, 51],
    '2004': [54, None, None, 54],
    '2005': [64, None, None, 64],
    '2006': [60, None, None, 60],
    '2007': [71, None, None, 71],
    '2008': [69, None, None, 69],
    '2009': [65, None, None, 65],
    '2010': [71, None, None, 71],
    '2011': [81, None, None, 81],
    '2012': [87, None, None, 87],
    '2013': [79, None, None, 79],
    '2014': [74, None, None, 74],
    '2015': [74, None, None, 74],
    '2016': [82, None, None, 82],
    '2017': [82, None, None, 82],
    '2018': [80, None, None, 80],
    '2019': [84, None, None, 84],
    '2020': [75, None, None, 75],
    '2021': [76, None, None, 76],
    '2022': [81, None, None, 81],
}

# Create a DataFrame
df_cadmium_emissions = pd.DataFrame(cadmium_emission_data)

# Display the table
display(df_cadmium_emissions)

# Set the index to years for easier plotting
years = df_cadmium_emissions.columns[3:].astype(int)
emissions = df_cadmium_emissions.iloc[:, 3:].fillna(0).sum(axis=0)

# Plotting cadmium emissions over the years
plt.figure(figsize=(12, 6))
plt.plot(years, emissions, marker='o', color='orange')
plt.title('Cadmium Emissions from Agriculture Over the Years')
plt.xlabel('Year')
plt.ylabel('Cadmium Emissions (kg)')
plt.xticks(years, rotation=45)
plt.grid()
plt.show()
# Out:
#         Source                        Sector SubSector  1990  1991  1992  \
# 0  Agriculture                          None      None  51.0  58.0  82.0
# 1  Agriculture             Animal Production      None   NaN   NaN   NaN
# 2  Agriculture               Crop Production      None   NaN   NaN   NaN
# 3  Agriculture  Agricultural Fuel Combustion      None  51.0  58.0  82.0
#
#    1993  1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  2004  \
# 0  66.0  60.0  68.0  65.0  67.0  53.0  57.0  54.0  53.0  54.0  51.0  54.0
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  66.0  60.0  68.0  65.0  67.0  53.0  57.0  54.0  53.0  54.0  51.0  54.0
#
#    2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0  64.0  60.0  71.0  69.0  65.0  71.0  81.0  87.0  79.0  74.0  74.0  82.0
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
# !pip install pandas matplotlib ipywidgets
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# Sample data for various pollutants (in kg or tons)
pollutants_data = {
    'Cadmium': {
        '1990': 51, '1991': 58, '1992': 82, '1993': 66, '1994': 60, '1995': 68,
        '1996': 65, '1997': 67, '1998': 53, '1999': 57, '2000': 54, '2001': 53,
        '2002': 54, '2003': 51, '2004': 54, '2005': 64, '2006': 60, '2007': 71,
        '2008': 69, '2009': 65, '2010': 71, '2011': 81, '2012': 87, '2013': 79,
        '2014': 74, '2015': 74, '2016': 82, '2017': 82, '2018': 80, '2019': 84,
        '2020': 75, '2021': 76, '2022': 81
    },
    'Nitrogen Oxides (NOx)': {
        '1990': 2085, '1991': 2397, '1992': 2910, '1993': 2656, '1994': 2261,
        '1995': 2457, '1996': 2536, '1997': 2524, '1998': 2211, '1999': 2312,
        '2000': 2244, '2001': 2050, '2002': 1950, '2003': 2104, '2004': 2125,
        '2005': 2118, '2006': 1962, '2007': 2476, '2008': 2514, '2009': 2673,
        '2010': 2811, '2011': 3378, '2012': 3317, '2013': 3069, '2014': 2885,
        '2015': 2698, '2016': 2885, '2017': 2798, '2018': 2804, '2019': 2865,
        '2020': 2637, '2021': 2684, '2022': 2865
    },
    'Sulfur Dioxide (SO2)': {
        '2006': 2091, '2007': 3800, '2008': 3310, '2009': 3485, '2010': 3438,
        '2011': 4562, '2012': 3427, '2013': None, '2014': None, '2015': None,
        '2016': 365, '2017': 303, '2018': 237, '2019': 220, '2020': 193,
        '2021': 163, '2022': 171
    },
    'Volatile Organic Compounds (VOC)': {
        '1990': 103575, '1991': 103623, '1992': 105303, '1993': 105108,
        '1994': 107494, '1995': 111493, '1996': 114513, '1997': 115213,
        '1998': 115640, '1999': 115953, '2000': 116864, '2001': 119865,
        '2002': 121010, '2003': 120561, '2004': 124493, '2005': 125620,
        '2006': 122989, '2007': 120857, '2008': 118926, '2009': 116192,
        '2010': 115243, '2011': 114136, '2012': 114756, '2013': 116109,
        '2014': 115255, '2015': 114039, '2016': 114622, '2017': 114915,
        '2018': 115653, '2019': 115428, '2020': 115202, '2021': 115705,
        '2022': 114947
    }
}

# Function to plot the selected pollutant
def plot_pollutant(pollutant):
    years = list(pollutants_data[pollutant].keys())
    emissions = list(pollutants_data[pollutant].values())

    plt.figure(figsize=(12, 6))
    plt.plot(years, emissions, marker='o', color='blue')
    plt.title(f'Evolution of {pollutant} Emissions Over the Years')
    plt.xlabel('Year')
    plt.ylabel(f'{pollutant} Emissions')
    plt.xticks(rotation=45)
    plt.grid()
    plt.show()

# Dropdown widget to select pollutant
pollutant_selector = widgets.Dropdown(
    options=list(pollutants_data.keys()),
    description='Select Pollutant:',
    value='Cadmium'
)

# Interactive plot
widgets.interactive(plot_pollutant, pollutant=pollutant_selector)
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
# interactive(children=(Dropdown(description='Select Pollutant:', options=('Cadmium', 'Nitrogen Oxides (NOx)', '…
