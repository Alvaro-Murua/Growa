# %% [markdown]
# <a href="https://colab.research.google.com/github/Alvaro-Murua/Growa-Inniative-/blob/main/Agricolal_production.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Estimates of specialized greenhouse operations, greenhouse area, and months of operation**
#
# Statistics Canada. Table 32-10-0019-01  Estimates of specialized greenhouse operations, greenhouse area, and months of operation
# DOI: https://doi.org/10.25318/3210001901-eng

# %%
# Importar las librerías necesarias
import pandas as pd

# Crear los datos en un diccionario
data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Greenhouse_Fruits_Vegetables': [0, 695, 695, 720, 795, 815, 820, 837, 861, 894, 889, 866, 843, 858, 892, 930, 920],
    'Greenhouse_Flowers_Plants': [0, 2290, 2180, 2055, 2130, 2080, 2035, 1940, 1872, 1811, 1703, 1646, 1620, 1615, 1557, 1545, 1523]
}

# Crear el DataFrame con pandas
df_greenhouse_operations = pd.DataFrame(data)

# Mostrar el DataFrame
df_greenhouse_operations
# Out:
#     Year  Greenhouse_Fruits_Vegetables  Greenhouse_Flowers_Plants
# 0   2007                             0                          0
# 1   2008                           695                       2290
# 2   2009                           695                       2180
# 3   2010                           720                       2055
# 4   2011                           795                       2130
# 5   2012                           815                       2080
# 6   2013                           820                       2035
# 7   2014                           837                       1940
# 8   2015                           861                       1872
# 9   2016                           894                       1811
# 10  2017                           889                       1703
# 11  2018                           866                       1646
# 12  2019                           843                       1620
# ...

# %% [markdown]
# **Direct payments to agriculture producers (x 1,000)**
#
# How to cite: Statistics Canada. Table 32-10-0106-01  Direct payments to agriculture producers (x 1,000)
# DOI: https://doi.org/10.25318/3210010601-eng

# %%
Direct payments to agriculture producers (x 1,000)

import pandas as pd

# Datos de los pagos directos a los productores agrícolas en Canadá (en miles de dólares)
data = {
    "Geography": ["Canada"] * 17,
    "Total direct payments": [
        4089433, 4133110, 3290322, 3138006, 3479924, 3404704,
        2685507, 2120698, 2134784, 2442148, 2435937, 2219067,
        3120980, 3459404, 5944084, 7345289, 6586916
    ],
    "Total privately funded programs": [
        188443, 316514, 118033, 163330, 166552, 276071,
        180268, 263522, 179227, 278964, 112521, 171233,
        251886, 200362, 327538, 278119, 179078
    ],
    "Total government funded programs": [
        3900990, 3816596, 3172289, 2974676, 3313372, 3128633,
        2505239, 1857176, 1955557, 2163184, 2323416, 2047834,
        2869094, 3259042, 5616546, 7067170, 6407838
    ],
    "Provincial Stabilization Programs": [
        878184, 655095, 695826, 210239, 459094, 504273,
        335321, 196538, 129771, 329567, 222995, 320967,
        268730, 408488, 168630, 335556, 671329
    ],
    "Crop Insurance": [
        566261, 598208, 810109, 1146642, 1304036, 1215618,
        1069476, 777446, 1107471, 1045184, 1226408, 893000,
        1408521, 1704119, 3749378, 4897368, 3881612
    ],
    "Livestock Insurance Programs": [
        110, 103, 50, 167, 877, 14009,
        13095, 2306, 5816, 32271, 3685, 10157,
        57765, 122148, 1859, 7684, 848
    ],
    "AgriInvest": [
        None, 305664, 357814, 328340, 424867, 452286,
        418620, 320989, 268853, 297341, 281386, 289132,
        261742, 261982, 258588, 265793, 314920
    ],
    "AgriStability": [
        43460, 592378, 789703, 833880, 740841, 726059,
        517437, 432894, 295718, 311025, 356462, 339995,
        365519, 452930, 366370, 406411, 396639
    ],
    "AgriRecovery": [
        None, 16034, 19142, 402475, 292904, 49709,
        570, 1289, 4106, 2703, 8965, 16653,
        16779, 17112, 422788, 392828, 47172
    ],
    "Total government funded programs and rebates": [
        3951711, 3868338, 3220263, 3016792, 3356677, 3182496,
        2550175, 1914811, 2005498, 2214672, 2381808, 2113778,
        2927776, 3337266, 5716493, 7189972, 6544090
    ],
    "Total rebates reducing expenses": [
        50721, 51742, 47974, 42116, 43305, 53863,
        44936, 57635, 49941, 51488, 58392, 65944,
        58682, 78224, 99947, 122802, 136252
    ],
    "Years": [
        2007, 2008, 2009, 2010, 2011, 2012,
        2013, 2014, 2015, 2016, 2017, 2018,
        2019, 2020, 2021, 2022, 2023
    ]
}

# Crear un DataFrame con los datos
df_agriculture_payments = pd.DataFrame(data)

# Mostrar el DataFrame
df_agriculture_payments.set_index('Years', inplace=True)
df_agriculture_payments
# Out:
#       Geography  Total direct payments  Total privately funded programs  \
# Years
# 2007     Canada                4089433                           188443
# 2008     Canada                4133110                           316514
# 2009     Canada                3290322                           118033
# 2010     Canada                3138006                           163330
# 2011     Canada                3479924                           166552
# 2012     Canada                3404704                           276071
# 2013     Canada                2685507                           180268
# 2014     Canada                2120698                           263522
# 2015     Canada                2134784                           179227
# 2016     Canada                2442148                           278964
# 2017     Canada                2435937                           112521
# 2018     Canada                2219067                           171233
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos de los pagos directos a los productores agrícolas en Canadá (en miles de dólares)
data = {
    "Geography": ["Canada"] * 17,
    "Total direct payments": [
        4089433, 4133110, 3290322, 3138006, 3479924, 3404704,
        2685507, 2120698, 2134784, 2442148, 2435937, 2219067,
        3120980, 3459404, 5944084, 7345289, 6586916
    ],
    "Total privately funded programs": [
        188443, 316514, 118033, 163330, 166552, 276071,
        180268, 263522, 179227, 278964, 112521, 171233,
        251886, 200362, 327538, 278119, 179078
    ],
    "Total government funded programs": [
        3900990, 3816596, 3172289, 2974676, 3313372, 3128633,
        2505239, 1857176, 1955557, 2163184, 2323416, 2047834,
        2869094, 3259042, 5616546, 7067170, 6407838
    ],
    "Provincial Stabilization Programs": [
        878184, 655095, 695826, 210239, 459094, 504273,
        335321, 196538, 129771, 329567, 222995, 320967,
        268730, 408488, 168630, 335556, 671329
    ],
    "Crop Insurance": [
        566261, 598208, 810109, 1146642, 1304036, 1215618,
        1069476, 777446, 1107471, 1045184, 1226408, 893000,
        1408521, 1704119, 3749378, 4897368, 3881612
    ],
    "Livestock Insurance Programs": [
        110, 103, 50, 167, 877, 14009,
        13095, 2306, 5816, 32271, 3685, 10157,
        57765, 122148, 1859, 7684, 848
    ],
    "AgriInvest": [
        None, 305664, 357814, 328340, 424867, 452286,
        418620, 320989, 268853, 297341, 281386, 289132,
        261742, 261982, 258588, 265793, 314920
    ],
    "AgriStability": [
        43460, 592378, 789703, 833880, 740841, 726059,
        517437, 432894, 295718, 311025, 356462, 339995,
        365519, 452930, 366370, 406411, 396639
    ],
    "AgriRecovery": [
        None, 16034, 19142, 402475, 292904, 49709,
        570, 1289, 4106, 2703, 8965, 16653,
        16779, 17112, 422788, 392828, 47172
    ],
    "Total government funded programs and rebates": [
        3951711, 3868338, 3220263, 3016792, 3356677, 3182496,
        2550175, 1914811, 2005498, 2214672, 2381808, 2113778,
        2927776, 3337266, 5716493, 7189972, 6544090
    ],
    "Total rebates reducing expenses": [
        50721, 51742, 47974, 42116, 43305, 53863,
        44936, 57635, 49941, 51488, 58392, 65944,
        58682, 78224, 99947, 122802, 136252
    ],
    "Years": [
        2007, 2008, 2009, 2010, 2011, 2012,
        2013, 2014, 2015, 2016, 2017, 2018,
        2019, 2020, 2021, 2022, 2023
    ]
}

# Crear un DataFrame con los datos
df_agriculture_payments = pd.DataFrame(data)

# Establecer 'Years' como índice
df_agriculture_payments.set_index('Years', inplace=True)

# Graficar los datos
plt.figure(figsize=(12, 6))
plt.plot(df_agriculture_payments.index, df_agriculture_payments['Total direct payments'], label='Total direct payments', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['Total privately funded programs'], label='Total privately funded programs', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['Total government funded programs'], label='Total government funded programs', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['Provincial Stabilization Programs'], label='Provincial Stabilization Programs', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['Crop Insurance'], label='Crop Insurance', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['Livestock Insurance Programs'], label='Livestock Insurance Programs', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['AgriInvest'], label='AgriInvest', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['AgriStability'], label='AgriStability', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['AgriRecovery'], label='AgriRecovery', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['Total government funded programs and rebates'], label='Total government funded programs and rebates', marker='o')
plt.plot(df_agriculture_payments.index, df_agriculture_payments['Total rebates reducing expenses'], label='Total rebates reducing expenses', marker='o')

# Configuraciones de la gráfica
plt.title('Direct Payments to Agricultural Producers in Canada (in $1,000)')
plt.xlabel('Years')
plt.ylabel('Payments (in $1,000)')
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.tight_layout()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# df_agriculture_payments.set_index('Years', inplace=True)
# df_agriculture_payments

# %% [markdown]
# **Estimated areas, yield, production, average farm price and total farm value of principal field crops, in metric and imperial units**
#
# Statistics Canada. Table 32-10-0359-01  Estimated areas, yield, production, average farm price and total farm value of principal field crops, in metric and imperial units
# DOI: https://doi.org/10.25318/3210035901-eng

# %%
import pandas as pd

# Datos de producción de cultivos principales en Canadá (en toneladas métricas)
data = {
    "Harvest disposition": [
        "Barley", "Canary seed", "Canola (rapeseed)", "Chick peas", "Corn for grain",
        "Flaxseed", "Lentils", "Mustard seed", "Oats", "Soybeans", "Sunflower seed",
        "Wheat, all", "Wheat, durum", "Wheat, spring", "Wheat, winter remaining"
    ],
    "2007": [
        10909800, 162500, 9611100, 224800, 11648700,
        633500, 733900, 124800, 4618400, 2686200, 123800,
        20090400, 3681400, 13805300, 2603700
    ],
    "2008": [
        11785800, 195000, 12644900, 67000, 10642800,
        861100, 1043200, 161100, 4272600, 3335900, 105600,
        28619200, 5519300, 18347700, 4752200
    ],
    "2009": [
        9528200, 197400, 12898100, 75500, 9796200,
        914900, 1530200, 208300, 2911500, 3581600, 101900,
        26949900, 5399600, 18472800, 3077500
    ],
    "2010": [
        7627200, 153500, 12788600, 128300, 12043300,
        418500, 2004800, 182000, 2451400, 4444600, 67600,
        23299600, 3024700, 17529300, 2745600
    ],
    "2011": [
        7891500, 128600, 14608100, 85600, 11358700,
        398900, 1573500, 130000, 3157600, 4466500, 19800,
        25288000, 4172100, 18018600, 3097300
    ],
    "2012": [
        8012300, 149700, 13868500, 161400, 13060100,
        491500, 1537900, 118600, 2829600, 5086400, 86900,
        27246000, 4626600, 18845400, 3774000
    ],
    "2013": [
        10281600, 131000, 18551000, 169400, 14190700,
        730700, 2261700, 154500, 3927600, 5355900, 51900,
        37589100, 6504500, 27238700, 3845900
    ],
    "2014": [
        7116800, 134900, 16410100, 123000, 11606400,
        883300, 1987000, 198000, 2976800, 6044800, 55000,
        29442100, 5192700, 21296300, 2953100
    ],
    "2015": [
        8256600, 148600, 18376500, 83500, 13679500,
        943100, 2540500, 123400, 3425000, 6456300, 72600,
        27647400, 5388700, 19962300, 2296400
    ],
    "2016": [
        8839400, 140300, 19599200, 75200, 13889000,
        591400, 3193800, 235600, 3231200, 6596500, 50600,
        32139900, 7761800, 20705200, 3672900
    ],
    "2017": [
        7891300, 145000, 21458100, 95600, 14095500,
        555100, 2558500, 121600, 3733000, 7716600, 57600,
        30377300, 4962200, 22559735, 2855300
    ],
    "2018": [
        8379700, 157600, 20723500, 311300, 13403900,
        492400, 2192100, 173600, 3436000, 7416600, 57900,
        32351900, 5784800, 24053200, 1700500
    ],
    "2019": [
        10382600, 175000, 19912300, 251500, 13403900,
        486100, 2382000, 134600, 4227300, 6145000, 62900,
        32669800, 5017000, 25952300, 1700500
    ],
    "2020": [
        10740600, 224700, 19484700, 214400, 13563300,
        578100, 2867700, 100000, 2898619, 6358500, 101300,
        35437200, 6571200, 26092100, 2773900
    ],
    "2021": [
        6983941, 127238, 14248281, 91288, 14610792,
        336638, 1593640, 60532, 2898619, 6224029, 74899,
        22422100, 3032490, 16161901, 3227759
    ],
    "2022": [
        9986681, 159306, 18849801, 145900, 14538878,
        473175, 2330638, 161781, 5226465, 6543158, 84054,
        34806782, 5790370, 26164184, 2852228
    ],
    "2023": [
        8905385, 112210, 19191655, 159100, 15420909,
        272736, 1801109, 170710, 2643058, 6980525, 92468,
        32946180, 4087467, 25520362, 3338351
    ],
    "2024": [
        7600182, 161843, 18980484, 327200, 15167588,
        265333, 2593457, 210678, 3017267, 7196652, 36136,
        34293320, 6033442, 25275355, 2984523
    ]
}

# Crear un DataFrame con los datos
df_crops_production = pd.DataFrame(data)

# Mostrar el DataFrame
df_crops_production.set_index('Harvest disposition', inplace=True)
df_crops_production
# Out:
#                              2007      2008      2009      2010      2011  \
# Harvest disposition
# Barley                   10909800  11785800   9528200   7627200   7891500
# Canary seed                162500    195000    197400    153500    128600
# Canola (rapeseed)         9611100  12644900  12898100  12788600  14608100
# Chick peas                 224800     67000     75500    128300     85600
# Corn for grain           11648700  10642800   9796200  12043300  11358700
# Flaxseed                   633500    861100    914900    418500    398900
# Lentils                    733900   1043200   1530200   2004800   1573500
# Mustard seed               124800    161100    208300    182000    130000
# Oats                      4618400   4272600   2911500   2451400   3157600
# Soybeans                  2686200   3335900   3581600   4444600   4466500
# Sunflower seed             123800    105600    101900     67600     19800
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Datos de los pagos directos a los productores agrícolas en Canadá (en miles de dólares)
data = {
    "Geography": ["Canada"] * 17,
    "Total direct payments": [
        4089433, 4133110, 3290322, 3138006, 3479924, 3404704,
        2685507, 2120698, 2134784, 2442148, 2435937, 2219067,
        3120980, 3459404, 5944084, 7345289, 6586916
    ],
    "Total privately funded programs": [
        188443, 316514, 118033, 163330, 166552, 276071,
        180268, 263522, 179227, 278964, 112521, 171233,
        251886, 200362, 327538, 278119, 179078
    ],
    "Total government funded programs": [
        3900990, 3816596, 3172289, 2974676, 3313372, 3128633,
        2505239, 1857176, 1955557, 2163184, 2323416, 2047834,
        2869094, 3259042, 5616546, 7067170, 6407838
    ],
    "Provincial Stabilization Programs": [
        878184, 655095, 695826, 210239, 459094, 504273,
        335321, 196538, 129771, 329567, 222995, 320967,
        268730, 408488, 168630, 335556, 671329
    ],
    "Crop Insurance": [
        566261, 598208, 810109, 1146642, 1304036, 1215618,
        1069476, 777446, 1107471, 1045184, 1226408, 893000,
        1408521, 1704119, 3749378, 4897368, 3881612
    ],
    "Livestock Insurance Programs": [
        110, 103, 50, 167, 877, 14009,
        13095, 2306, 5816, 32271, 3685, 10157,
        57765, 122148, 1859, 7684, 848
    ],
    "AgriInvest": [
        None, 305664, 357814, 328340, 424867, 452286,
        418620, 320989, 268853, 297341, 281386, 289132,
        261742, 261982, 258588, 265793, 314920
    ],
    "AgriStability": [
        43460, 592378, 789703, 833880, 740841, 726059,
        517437, 432894, 295718, 311025, 356462, 339995,
        365519, 452930, 366370, 406411, 396639
    ],
    "AgriRecovery": [
        None, 16034, 19142, 402475, 292904, 49709,
        570, 1289, 4106, 2703, 8965, 16653,
        16779, 17112, 422788, 392828, 47172
    ],
    "Total government funded programs and rebates": [
        3951711, 3868338, 3220263, 3016792, 3356677, 3182496,
        2550175, 1914811, 2005498, 2214672, 2381808, 2113778,
        2927776, 3337266, 5716493, 7189972, 6544090
    ],
    "Total rebates reducing expenses": [
        50721, 51742, 47974, 42116, 43305, 53863,
        44936, 57635, 49941, 51488, 58392, 65944,
        58682, 78224, 99947, 122802, 136252
    ],
    "Years": [
        2007, 2008, 2009, 2010, 2011, 2012,
        2013, 2014, 2015, 2016, 2017, 2018,
        2019, 2020, 2021, 2022, 2023
    ]
}

# Crear un DataFrame con los datos
df_agriculture_payments = pd.DataFrame(data)

# Establecer 'Years' como índice
df_agriculture_payments.set_index('Years', inplace=True)

# Gráfica 1: Gráfico de líneas estilizado
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
colors = sns.color_palette("tab10")

for column, color in zip(df_agriculture_payments.columns, colors):
    plt.plot(df_agriculture_payments.index, df_agriculture_payments[column], label=column, marker='o', color=color)

plt.title('Pagos Directos a Productores Agrícolas en Canadá (en $1,000)', fontsize=16)
plt.xlabel('Años', fontsize=12)
plt.ylabel('Pagos (en $1,000)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()

# Mostrar la primera gráfica
plt.show()

# Gráfica 2: Gráfico de áreas apiladas
plt.figure(figsize=(12, 6))
df_agriculture_payments.plot.area(stacked=True, alpha=0.6, cmap='tab10')

plt.title('Contribuciones de Programas a los Pagos Directos (en $1,000)', fontsize=16)
plt.xlabel('Años', fontsize=12)
plt.ylabel('Pagos (en $1,000)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()

# Mostrar la segunda gráfica
plt.show()

# %% [markdown]
# Farm product price index (FPPI), annual (2007=100)1, 2, 3

# %% [markdown]
# **Net farm income (x 1,000)1**
#
# Statistics Canada. Table 32-10-0052-01  Net farm income (x 1,000)
# DOI: https://doi.org/10.25318/3210005201-eng

# %%
import pandas as pd

# Crear un diccionario con los datos
data = {
    "Income components": [
        "Cash receipts, total",
        "Operating expenses after rebates",
        "Net cash income",
        "Income-in-kind",
        "Depreciation charges",
        "Realized net income",
        "Value of inventory change",
        "Net income, total"
    ],
    "2007": [
        40865566, 33756407, 7109159, 42826, 5033501,
        2118484, -988628, 1129856
    ],
    "2008": [
        46059835, 37128162, 8931673, 42854, 5220724,
        3753804, 3260137, 7013941
    ],
    "2009": [
        44559519, 36078927, 8480592, 39929, 5497759,
        3022761, -175920, 2846841
    ],
    "2010": [
        44455276, 35424634, 9030642, 41445, 5509504,
        3562583, -1123431, 2439153
    ],
    "2011": [
        49889876, 38403018, 11486858, 45439, 5870596,
        5661700, 476218, 6137918
    ],
    "2012": [
        54227613, 41682703, 12544910, 45382, 6080957,
        6509335, 145318, 6654653
    ],
    "2013": [
        55627787, 43090807, 12536980, 46482, 6352458,
        6231003, 5991414, 12222417
    ],
    "2014": [
        58285425, 44507181, 13778244, 56314, 6678413,
        7156145, -2781173, 4374972
    ],
    "2015": [
        60076137, 45985502, 14090636, 61336, 7134267,
        7017705, -121895, 6895810
    ],
    "2016": [
        60699813, 46521121, 14178692, 55690, 7312896,
        6921486, 1198401, 8119888
    ],
    "2017": [
        62433143, 48279624, 14153519, 56217, 7601930,
        6607806, 1361247, 7969053
    ],
    "2018": [
        62800068, 51100244, 11699824, 56183, 7845376,
        3910631, 49767, 3960397
    ],
    "2019": [
        66218775, 54395006, 11823769, 54923, 8140210,
        3738482, 403776, 4142259
    ],
    "2020": [
        71763185, 55825197, 15937987, 55104, 8456630,
        7536461, -1482669, 6053791
    ],
    "2021": [
        83068913, 61119998, 21948914, 61633, 9226183,
        12784364, -7249297, 5535067
    ],
    "2022": [
        95344373, 73006450, 22337923, 65669, 10141362,
        12262230, 9466814, 21729043
    ],
    "2023": [
        99574431, 74717545, 24856886, 71496, 10418066,
        14510316, -1662381, 12847935
    ],
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Mostrar la tabla con los componentes de ingreso como índice
df.set_index("Income components", inplace=True)

# Mostrar la tabla
df
# Out:
#                                       2007      2008      2009      2010  \
# Income components
# Cash receipts, total              40865566  46059835  44559519  44455276
# Operating expenses after rebates  33756407  37128162  36078927  35424634
# Net cash income                    7109159   8931673   8480592   9030642
# Income-in-kind                       42826     42854     39929     41445
# Depreciation charges               5033501   5220724   5497759   5509504
# Realized net income                2118484   3753804   3022761   3562583
# Value of inventory change          -988628   3260137   -175920  -1123431
# Net income, total                  1129856   7013941   2846841   2439153
#
#                                       2011      2012      2013      2014  \
# Income components
# Cash receipts, total              49889876  54227613  55627787  58285425
# Operating expenses after rebates  38403018  41682703  43090807  44507181
# ...

# %% [markdown]
# **Agriculture value added account **(x 1,000)1
#
#
# Statistics Canada. Table 32-10-0048-01  Agriculture value added account (x 1,000)
# DOI: https://doi.org/10.25318/3210004801-eng
# [texto del vínculo](https://)

# %%
import pandas as pd

# Definir los datos
data = {
    "Geography": ["Canada"] * 16,
    "Reference period": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    "Total value of production": [47723127, 57598197, 52564490, 51301010, 59458454, 64060373, 71331897, 66598490, 69297174, 71085183, 72686236, 72014720, 76705466, 82116437, 88867243, 118592285],
    "Sales of agricultural products": [41988134, 47389006, 46585820, 46480942, 52602040, 57172707, 59296095, 63523243, 63885068, 63950186, 65269818, 65998266, 68929674, 75412671, 84924660, 96160150],
    "Sales to other farms": [5309460, 5548429, 5391460, 5215887, 6245959, 6407158, 6416812, 7424962, 6011843, 5763022, 5346755, 5488402, 5909596, 7193155, 7902262, 8467287],
    "Sales to other sectors": [36678674, 41840578, 41194360, 41265056, 46356081, 50765550, 52879284, 56098281, 57873225, 58187164, 59923063, 60509864, 63020078, 68219516, 77022398, 87692863],
    "Sales of secondary production": [97459, 86148, 74837, 52215, 53871, 57359, 62996, 66446, 68129, 70501, 74143, 71138, 77717, 84265, 102431, 127048],
    "Other sources of income": [6583337, 6820052, 6039824, 5849839, 6280886, 6639606, 5934910, 5733659, 5404537, 5810404, 5924811, 5839367, 7239375, 8047067, 11027817, 12694867],
    "Custom work receipts": [2315882, 2487089, 2554211, 2507176, 2585045, 2991337, 3007696, 3346134, 2963952, 3044662, 3180721, 3297647, 3793065, 4229046, 4588959, 4802030],
    "Program payments": [4089433, 4133110, 3290322, 3138006, 3479924, 3404704, 2685507, 2120698, 2134784, 2442148, 2435937, 2219067, 3120980, 3459404, 5944084, 7345315],
    "Government rebates": [50721, 51742, 47974, 42116, 43305, 53863, 44936, 57635, 49941, 51488, 58392, 65944, 58682, 78224, 99947, 122802],
    "Farm land rent": [127301, 148111, 147317, 162542, 172612, 189703, 196772, 209192, 255861, 272106, 249760, 256708, 266648, 280392, 394826, 424720],
    "Own account production uses": [-945802, 3302991, -135991, -1081986, 521657, 190700, 6037895, -2724859, -60559, 1254092, 1417463, 105950, 458699, -1427565, -7187665, 9610220],
    "Income-in-kind": [42826, 42854, 39929, 41445, 45439, 45382, 46482, 56314, 61336, 55690, 56217, 56183, 54923, 55104, 61633, 67305],
    "Value of inventory change": [-988628, 3260137, -175920, -1123431, 476218, 145318, 5991414, -2781173, -121895, 1198401, 1361247, 49767, 403776, -1482669, -7249297, 9542915],
    "Expenses on inputs": [32451057, 35889112, 35367099, 34466615, 38176090, 41552974, 42413360, 44903288, 44275623, 44104324, 45078054, 47142428, 50080901, 52880337, 59019754, 69963699],
    "Expenses on inputs from other farms": [5436760, 5696540, 5538778, 5378428, 6418572, 6596861, 6613583, 7634154, 6267704, 6035128, 5596515, 5745111, 6176244, 7473547, 8297088, 8892007],
    "Expenses on inputs from other sectors": [27014297, 30192572, 29828321, 29088186, 31757518, 34956114, 35799777, 37269133, 38007919, 38069195, 39481539, 41397318, 43904656, 45406790, 50722665, 61071692],
    "Business taxes": [544551, 547563, 536755, 534794, 534150, 545062, 568826, 586898, 612303, 639681, 677335, 703392, 751437, 776109, 801258, 818097],
    "Gross value added": [14727520, 21161523, 16660637, 16299602, 20748214, 21962337, 28349711, 21108305, 24409248, 26341178, 26930846, 24168900, 25873128, 28459990, 29046231, 47810490],
    "Depreciation": [5033501, 5220724, 5497759, 5509504, 5870596, 6080957, 6352458, 6678413, 7134267, 7312896, 7601930, 7845376, 8140210, 8456630, 9226183, 10140361],
    "Net value added": [9694019, 15940799, 11162877, 10790098, 14877618, 15881380, 21997253, 14429892, 17274982, 19028282, 19328916, 16323524, 17732918, 20003360, 19820049, 37670128],
    "Non-family wages": [2481551, 2580669, 2613361, 2747481, 2848897, 2994215, 3126431, 3240386, 3339925, 3480390, 3633544, 3874571, 4309231, 4582259, 4760888, 5144391],
    "Cash and share rent to non-operators": [1296299, 1522929, 1468057, 1473343, 1627457, 1769600, 1987784, 2003796, 2133906, 2283260, 2386794, 2442721, 2566567, 2702472, 2736254, 3109724],
    "Interest": [3008770, 2968616, 2392401, 2229466, 2320326, 2449134, 2586137, 2703294, 2719118, 2855410, 3040176, 3657007, 4226176, 4066472, 3983654, 5029168],
    "Corporation profits": [702848, 674933, 666331, 677062, 678075, 710179, 740193, 753134, 804295, 877373, 892855, 903245, 917583, 964868, 966301, 1320223],
    "Total taxes": [341168, 349950, 362214, 368025, 382559, 398990, 409771, 428301, 438835, 451394, 463847, 484495, 496564, 505856, 524551, 574029]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Mostrar el DataFrame
df

agricultural_data = pd.DataFrame(data)
agricultural_data

# %%
# !pip install pandas plotly dash
import pandas as pd
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px

# Datos de ejemplo (aquí puedes cargar tus datos)
data = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    "Total value of production": [47723127, 57598197, 52564490, 51301010, 59458454, 64060373, 71331897, 66598490, 69297174, 71085183, 72686236, 72014720, 76705466, 82116437, 88867243, 118592285],
    "Sales of agricultural products": [41988134, 47389006, 46585820, 46480942, 52602040, 57172707, 59296095, 63523243, 63885068, 63950186, 65269818, 65998266, 68929674, 75412671, 84924660, 96160150],
    # Agrega otras columnas según sea necesario
}

# Crear un DataFrame
df = pd.DataFrame(data)

# Inicializar la aplicación Dash
app = dash.Dash(__name__)

# Diseño de la aplicación
app.layout = html.Div([
    html.H1("Análisis de Producción Agrícola en Canadá"),

    dcc.Dropdown(
        id='year-dropdown',
        options=[{'label': str(year), 'value': year} for year in df['Year']],
        value=2007,  # Valor predeterminado
        clearable=False
    ),

    dcc.Graph(id='production-graph')
])

# Callback para actualizar la gráfica basada en el año seleccionado
@app.callback(
    Output('production-graph', 'figure'),
    Input('year-dropdown', 'value')
)
def update_graph(selected_year):
    filtered_df = df[df['Year'] == selected_year]

    fig = px.bar(filtered_df, x='Year',
                  y=['Total value of production', 'Sales of agricultural products'],
                  title=f'Datos para el año {selected_year}',
                  labels={'value': 'Monto ($)', 'variable': 'Tipo'},
                  barmode='group')

    return fig

# Ejecutar la aplicación
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 31.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# Datos proporcionados
data = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
             2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Area Planted (acres)": [19620, 18575, 16377, 16780, 17895,
                              17776, 17598, 17560, 17494, 17144,
                              16203, 16208, 15360, 15498, 16119,
                              15360, 15426],
    "Average Yield per Acre (pounds)": [66900, 67100, 68200, 66400, 60700,
                                         75500, 74300, 59800, 59500, 65000,
                                         69800, None, None, None, None,
                                         None, None],
    "Total Production (tons)": [656043, 620748, 553678, 543054, 520970,
                                607755, 553996, 397201, 473263, 552672,
                                542771, 548332, 540448, 542417, 567705,
                                583054, 598611],
    "Farm Gate Value (dollars)": [81940, 75915, 86856, 76500, 80225,
                                   85774, 65002, 80642, 93025, 111768,
                                   109876, 106820, 109857, 116706,
                                   117162, 128375, 135196],
    "Area Harvested (acres)": [19605, 18515, 16232, 16366, 17163,
                                16095, 14921, 13295, 15905, 17011,
                                15551, 15296, 14684, 14668, 15424,
                                15131, 14994],
    "Marketed Production (tons)": [656043, 620745, 553661, 522267, 520939,
                                    593343, 542178, 395173, 473073,
                                    552621, 527964, 553259, 530963,
                                    540551, 566429, 581326, 593726],
}

# Crear el DataFrame
vegetable_data = pd.DataFrame(data)

# Mostrar el DataFrame
import pandas as pd
from IPython.display import display

# Mostrar la tabla
display(vegetable_data)
# Out:
#     Year  Area Planted (acres)  Average Yield per Acre (pounds)  \
# 0   2007                 19620                          66900.0
# 1   2008                 18575                          67100.0
# 2   2009                 16377                          68200.0
# 3   2010                 16780                          66400.0
# 4   2011                 17895                          60700.0
# 5   2012                 17776                          75500.0
# 6   2013                 17598                          74300.0
# 7   2014                 17560                          59800.0
# 8   2015                 17494                          59500.0
# 9   2016                 17144                          65000.0
# 10  2017                 16203                          69800.0
# 11  2018                 16208                              NaN
# 12  2019                 15360                              NaN
# 13  2020                 15498                              NaN
# ...

# %%
# !pip install pandas plotly dash
import pandas as pd
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px

# Datos de ejemplo
data = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Area Planted (acres)": [19620, 18575, 16377, 16780, 17895, 17776, 17598, 17560, 17494, 17144, 16203, 16208, 15360, 15498, 16119, 15360, 15426],
    "Average Yield per Acre (pounds)": [66900.0, 67100.0, 68200.0, 66400.0, 60700.0, 75500.0, 74300.0, 59800.0, 59500.0, 65000.0, 69800.0, None, None, None, None, None, None],
    "Total Production (tons)": [656043, 620748, 553678, 543054, 520970, 607755, 553996, 397201, 473263, 552672, 542771, 548332, 540448, 542417, 567705, 583054, 598611],
    "Farm Gate Value (dollars)": [81940, 75915, 86856, 76500, 80225, 85774, 65002, 80642, 93025, 111768, 109876, 106820, 109857, 116706, 117162, 128375, 135196],
}

# Crear un DataFrame
df = pd.DataFrame(data)

# Inicializar la aplicación Dash
app = dash.Dash(__name__)

# Diseño de la aplicación
app.layout = html.Div([
    html.H1("Datos Agrícolas en Canadá"),

    dcc.Dropdown(
        id='year-dropdown',
        options=[{'label': str(year), 'value': year} for year in df['Year']],
        value=2007,  # Valor predeterminado
        clearable=False
    ),

    dcc.Dropdown(
        id='variable-dropdown',
        options=[
            {'label': 'Area Planted (acres)', 'value': 'Area Planted (acres)'},
            {'label': 'Average Yield per Acre (pounds)', 'value': 'Average Yield per Acre (pounds)'},
            {'label': 'Total Production (tons)', 'value': 'Total Production (tons)'},
            {'label': 'Farm Gate Value (dollars)', 'value': 'Farm Gate Value (dollars)'},
        ],
        value='Total Production (tons)',  # Valor predeterminado
        clearable=False
    ),

    dcc.Graph(id='agriculture-map')
])

# Callback para actualizar la gráfica basada en el año y variable seleccionados
@app.callback(
    Output('agriculture-map', 'figure'),
    Input('year-dropdown', 'value'),
    Input('variable-dropdown', 'value')
)
def update_graph(selected_year, selected_variable):
    filtered_df = df[df['Year'] == selected_year]

    # Crear un gráfico
    fig = px.bar(filtered_df, x='Year', y=selected_variable,
                  title=f'Datos para el año {selected_year}',
                  labels={'value': selected_variable, 'Year': 'Año'})

    return fig

# Ejecutar la aplicación
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import pandas as pd
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px

# Datos de ejemplo
data = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Area Planted (acres)": [19620, 18575, 16377, 16780, 17895, 17776, 17598, 17560, 17494, 17144, 16203, 16208, 15360, 15498, 16119, 15360, 15426],
    "Average Yield per Acre (pounds)": [66900.0, 67100.0, 68200.0, 66400.0, 60700.0, 75500.0, 74300.0, 59800.0, 59500.0, 65000.0, 69800.0, None, None, None, None, None, None],
    "Total Production (tons)": [656043, 620748, 553678, 543054, 520970, 607755, 553996, 397201, 473263, 552672, 542771, 548332, 540448, 542417, 567705, 583054, 598611],
    "Farm Gate Value (dollars)": [81940, 75915, 86856, 76500, 80225, 85774, 65002, 80642, 93025, 111768, 109876, 106820, 109857, 116706, 117162, 128375, 135196],
}

# Crear un DataFrame
df = pd.DataFrame(data)

# Inicializar la aplicación Dash
app = dash.Dash(__name__)

# Diseño de la aplicación
app.layout = html.Div([
    html.H1("Datos Agrícolas en Canadá", style={'textAlign': 'center'}),

    dcc.Dropdown(
        id='variable-dropdown',
        options=[
            {'label': 'Area Planted (acres)', 'value': 'Area Planted (acres)'},
            {'label': 'Average Yield per Acre (pounds)', 'value': 'Average Yield per Acre (pounds)'},
            {'label': 'Total Production (tons)', 'value': 'Total Production (tons)'},
            {'label': 'Farm Gate Value (dollars)', 'value': 'Farm Gate Value (dollars)'},
        ],
        value='Total Production (tons)',  # Valor predeterminado
        clearable=False,
        style={'width': '50%', 'margin': 'auto'}
    ),

    dcc.Graph(id='agriculture-line-graph', style={'margin': 'auto', 'width': '80%', 'height': '400px'})
], style={'textAlign': 'center'})

# Callback para actualizar la gráfica basada en la variable seleccionada
@app.callback(
    Output('agriculture-line-graph', 'figure'),
    Input('variable-dropdown', 'value')
)
def update_graph(selected_variable):
    # Crear un gráfico de líneas
    fig = px.line(df, x='Year', y=selected_variable,
                   title=f'Datos de {selected_variable}',
                   labels={'value': selected_variable, 'Year': 'Año'},
                   line_shape='linear', markers=True)

    # Estilo minimalista
    fig.update_layout(
        plot_bgcolor='white',
        xaxis=dict(showgrid=False),
        yaxis=dict(showgrid=False),
        title_font=dict(size=20),
        font=dict(size=14),
    )

    return fig

# Ejecutar la aplicación
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import pandas as pd

# Datos proporcionados
data_cucumbers = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
             2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Area Planted (acres)": [6186, 4841, 6616, 6028, 5782,
                              6016, 6250, 6485, 6719, 6953,
                              6256, 6011, 6091, 5887, 6223,
                              6287, 6104],
    "Average Yield per Acre (pounds)": [18400, 20000, 23400, 20400, 20900,
                                         19400, 21000, 24100, 18500, 20700,
                                         23400, None, None, None, None,
                                         None, None],
    "Total Production (tons)": [49207, 46954, 74797, 59492, 54111,
                                56983, 64032, 74506, 61214, 70857,
                                68569, 63157, 65416, 63553, 63626,
                                66891, 65271],
    "Farm Gate Value (dollars)": [19589, 19001, 32862, 26020, 23496,
                                   26887, 32098, 34490, 32591, 40082,
                                   35485, None, 37491, None, 46413,
                                   49303, 49947],
    "Area Harvested (acres)": [5355, 4699, 6392, 5842, 5174,
                                5884, 6097, 6173, 6633, 6842,
                                5854, 5816, 6007, 5697, 5980,
                                5947, 5791],
    "Marketed Production (tons)": [49175, 43487, 71020, 59469, 51867,
                                    56972, 63052, 73097, 59699,
                                    70095, 67312, 62635, 65393,
                                    62345, 62277, 64709, 64051],
}

# Crear el DataFrame
cucumber_data = pd.DataFrame(data_cucumbers)

# Mostrar el DataFrame
from IPython.display import display

# Mostrar la tabla
display(cucumber_data)
# Out:
#     Year  Area Planted (acres)  Average Yield per Acre (pounds)  \
# 0   2007                  6186                          18400.0
# 1   2008                  4841                          20000.0
# 2   2009                  6616                          23400.0
# 3   2010                  6028                          20400.0
# 4   2011                  5782                          20900.0
# 5   2012                  6016                          19400.0
# 6   2013                  6250                          21000.0
# 7   2014                  6485                          24100.0
# 8   2015                  6719                          18500.0
# 9   2016                  6953                          20700.0
# 10  2017                  6256                          23400.0
# 11  2018                  6011                              NaN
# 12  2019                  6091                              NaN
# 13  2020                  5887                              NaN
# ...

# %%
import pandas as pd

# Datos proporcionados sobre lechugas
data_lettuce = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
             2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Area Planted (acres)": [8310, 9115, 13550, 11556, 9361,
                              9417, 9540, 9739, 9901, 10231,
                              9822, 9713, 9643, 8319, 8451,
                              9543, 9515],
    "Average Yield per Acre (pounds)": [17600, 20100, 15300, 14100, 16400,
                                         20000, 19600, 19800, 19900, 20400,
                                         20200, None, None, None, None,
                                         None, None],
    "Total Production (tons)": [71760, 77623, 87571, 76575, 70408,
                                87163, 85870, 90461, 93346, 100829,
                                95464, 94529, 93588, 73648, 83348,
                                87481, 84015],
    "Farm Gate Value (dollars)": [39440, 46425, 60961, 59431, 49457,
                                   54515, 64787, 69100, 76063, 84336,
                                   78997, 81844, 82370, 77971, 84967,
                                   100798, 99948],
    "Area Harvested (acres)": [8140, 7735, 11420, 10835, 8600,
                                8737, 8754, 9127, 9384, 9876,
                                9468, 9397, 9330, 8024, 7928,
                                8789, 8645],
    "Marketed Production (tons)": [70510, 77605, 82147, 76560, 69777,
                                    74750, 85868, 90455, 93333,
                                    100821, 95380, 94489, 93582,
                                    70949, 83311, 86856, 82680],
}

# Crear el DataFrame
lettuce_data = pd.DataFrame(data_lettuce)

# Mostrar el DataFrame
from IPython.display import display

# Mostrar la tabla
display(lettuce_data)
# Out:
#     Year  Area Planted (acres)  Average Yield per Acre (pounds)  \
# 0   2007                  8310                          17600.0
# 1   2008                  9115                          20100.0
# 2   2009                 13550                          15300.0
# 3   2010                 11556                          14100.0
# 4   2011                  9361                          16400.0
# 5   2012                  9417                          20000.0
# 6   2013                  9540                          19600.0
# 7   2014                  9739                          19800.0
# 8   2015                  9901                          19900.0
# 9   2016                 10231                          20400.0
# 10  2017                  9822                          20200.0
# 11  2018                  9713                              NaN
# 12  2019                  9643                              NaN
# 13  2020                  8319                              NaN
# ...

# %%
import pandas as pd

# Datos proporcionados sobre sandías
data_watermelons = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
             2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Area Planted (acres)": [890, 900, 1995, 1810, 1406,
                              1335, 1982, 1942, 1823, 1666,
                              1712, 1720, 1776, 1651, 1896,
                              2004, 2076],
    "Average Yield per Acre (pounds)": [24400, 25400, 18500, 22900, 28600,
                                         38600, 27400, 33100, 36300,
                                         36100, 41300, None, None, None,
                                         None, None, None],
    "Total Production (tons)": [10540, 11060, 16037, 20626, 19902,
                                25295, 25296, 29861, 30732, 27709,
                                28881, None, 36312, 36996, 38338,
                                38594, 39995],
    "Farm Gate Value (dollars)": [3275, 3545, 5361, 7242, 7409,
                                   6901, 7962, 8621, 9540, 10342,
                                   8401, 11847, 13649, 15559, 17791,
                                   18322, 19866],
    "Area Harvested (acres)": [865, 870, 1735, 1801, 1391,
                                1312, 1848, 1805, 1693, 1535,
                                1400, 1681, 1746, 1632, 1859,
                                1993, 2066],
    "Marketed Production (tons)": [10535, 11053, 16036, 20606, 19902,
                                    25288, 25294, 29861, 30732,
                                    27180, 28880, None, 36226,
                                    36989, 38338, 38594, 39995],
}

# Crear el DataFrame
watermelon_data = pd.DataFrame(data_watermelons)

# Mostrar el DataFrame
from IPython.display import display

# Mostrar la tabla
display(watermelon_data)
# Out:
#     Year  Area Planted (acres)  Average Yield per Acre (pounds)  \
# 0   2007                   890                          24400.0
# 1   2008                   900                          25400.0
# 2   2009                  1995                          18500.0
# 3   2010                  1810                          22900.0
# 4   2011                  1406                          28600.0
# 5   2012                  1335                          38600.0
# 6   2013                  1982                          27400.0
# 7   2014                  1942                          33100.0
# 8   2015                  1823                          36300.0
# 9   2016                  1666                          36100.0
# 10  2017                  1712                          41300.0
# 11  2018                  1720                              NaN
# 12  2019                  1776                              NaN
# 13  2020                  1651                              NaN
# ...

# %%
import pandas as pd

# Datos proporcionados sobre otros melones
data_melons = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
             2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Area Planted (acres)": [1070, 1230, 1320, 1238, 1180,
                              1458, 1698, 1786, 1759, 1664,
                              1413, 1247, 1148, 1056, 1151,
                              1177, 1145],
    "Average Yield per Acre (pounds)": [20200, 21800, 22800, 22400, 21800,
                                         25300, 24300, 24100, 22600,
                                         24000, 23400, None, None, None,
                                         None, None, None],
    "Total Production (tons)": [10575, 13045, 14415, 13219, 12523,
                                18210, 19341, 21434, 19543, 19537,
                                15793, 15717, 13748, 12189, 12059,
                                11909, 11410],
    "Farm Gate Value (dollars)": [5520, 6360, 7013, 7114, 6327,
                                   8624, 10100, 10332, 10586, 10344,
                                   8611, 9057, 8737, 9012, 9364,
                                   9330, 9210],
    "Area Harvested (acres)": [1045, 1195, 1265, 1181, 1148,
                                1441, 1594, 1781, 1726, 1630,
                                1347, 1228, 1089, 1001, 1003,
                                1009, 977],
    "Marketed Production (tons)": [10525, 13045, 14415, 13215, 12516,
                                    18209, 19283, 21434, 19543,
                                    19536, 15789, 15717, 13748,
                                    12165, 12059, 11767, 11329],
}

# Crear el DataFrame
melon_data = pd.DataFrame(data_melons)

# Mostrar el DataFrame
from IPython.display import display

# Mostrar la tabla
display(melon_data)
# Out:
#     Year  Area Planted (acres)  Average Yield per Acre (pounds)  \
# 0   2007                  1070                          20200.0
# 1   2008                  1230                          21800.0
# 2   2009                  1320                          22800.0
# 3   2010                  1238                          22400.0
# 4   2011                  1180                          21800.0
# 5   2012                  1458                          25300.0
# 6   2013                  1698                          24300.0
# 7   2014                  1786                          24100.0
# 8   2015                  1759                          22600.0
# 9   2016                  1664                          24000.0
# 10  2017                  1413                          23400.0
# 11  2018                  1247                              NaN
# 12  2019                  1148                              NaN
# 13  2020                  1056                              NaN
# ...

# %%
import pandas as pd

# Datos proporcionados sobre el brócoli
data_broccoli = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
             2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Area Planted (acres)": [10935, 9470, 11437, 11258, 10265,
                              10261, 10258, 10256, 10253, 10566,
                              10929, 11293, 11244, 10683, 10750,
                              10247, 10142],
    "Average Yield per Acre (pounds)": [8200, 8200, 9100, 8700, 7800,
                                         8100, 8500, 9000, 9500,
                                         9400, 9200, None, None, None,
                                         None, None, None],
    "Total Production (tons)": [42723, 35740, 46944, 42910, 36721,
                                39138, 40028, 43657, 45082, 46612,
                                46773, 46768, 46642, 42163, 44873,
                                39720, 38732],
    "Farm Gate Value (dollars)": [36775, 33735, 39717, 35594, 33553,
                                   41216, 46715, 54539, 60980, 59369,
                                   72010, 75850, 79364, 77937, 84679,
                                   78772, 79715],
    "Area Harvested (acres)": [10405, 8685, 10321, 9909, 9375,
                                9645, 9460, 9674, 9522, 9941,
                                10209, 10129, 10153, 9740, 9268,
                                9054, 8777],
    "Marketed Production (tons)": [42698, 35565, 45722, 42900, 36669,
                                    39075, 40027, 43628, 45057,
                                    46414, 46773, 46667, 45637,
                                    40061, 44107, 39216, 37900],
}

# Crear el DataFrame
broccoli_data = pd.DataFrame(data_broccoli)

# Mostrar el DataFrame
from IPython.display import display

# Mostrar la tabla
display(broccoli_data)
# Out:
#     Year  Area Planted (acres)  Average Yield per Acre (pounds)  \
# 0   2007                 10935                           8200.0
# 1   2008                  9470                           8200.0
# 2   2009                 11437                           9100.0
# 3   2010                 11258                           8700.0
# 4   2011                 10265                           7800.0
# 5   2012                 10261                           8100.0
# 6   2013                 10258                           8500.0
# 7   2014                 10256                           9000.0
# 8   2015                 10253                           9500.0
# 9   2016                 10566                           9400.0
# 10  2017                 10929                           9200.0
# 11  2018                 11293                              NaN
# 12  2019                 11244                              NaN
# 13  2020                 10683                              NaN
# ...

# %%
import pandas as pd

# Datos proporcionados sobre las zanahorias
data_carrots = {
    "Year": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
             2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Area Planted (acres)": [22605, 21005, 21967, 21611, 23476,
                              22969, 23029, 22583, 22318, 22091,
                              21404, 20618, 20907, 22729, 23911,
                              23402, 21758],
    "Average Yield per Acre (pounds)": [30400, 29600, 38500, 44400, 43100,
                                         39900, 38200, 35800, 38000,
                                         37900, 40400, None, None, None,
                                         None, None, None],
    "Total Production (tons)": [338155, 305420, 397050, 456778, 478654,
                                449363, 417328, 379570, 414546, 406179,
                                425081, 398529, 400121, 397081, 391620,
                                379157, 372372],
    "Farm Gate Value (dollars)": [67710, 66975, 84195, 97071, 99731,
                                   93576, 104911, 110612, 125955, 128650,
                                   132805, 129170, 139818, 136105, 139265,
                                   149420, 154958],
    "Area Harvested (acres)": [22225, 20655, 20625, 20581, 22187,
                                22509, 21847, 21207, 21845, 21435,
                                21061, 20095, 19756, 21333, 21737,
                                21244, 19815],
    "Marketed Production (tons)": [318700, 287220, 370724, 443295, 468380,
                                    439842, 404073, 359952, 414539,
                                    395567, 416105, 392861, 391423,
                                    390924, 385619, 365712, 362493],
}

# Crear el DataFrame
carrots_data = pd.DataFrame(data_carrots)

# Mostrar el DataFrame
from IPython.display import display

# Mostrar la tabla
display(carrots_data)
# Out:
#     Year  Area Planted (acres)  Average Yield per Acre (pounds)  \
# 0   2007                 22605                          30400.0
# 1   2008                 21005                          29600.0
# 2   2009                 21967                          38500.0
# 3   2010                 21611                          44400.0
# 4   2011                 23476                          43100.0
# 5   2012                 22969                          39900.0
# 6   2013                 23029                          38200.0
# 7   2014                 22583                          35800.0
# 8   2015                 22318                          38000.0
# 9   2016                 22091                          37900.0
# 10  2017                 21404                          40400.0
# 11  2018                 20618                              NaN
# 12  2019                 20907                              NaN
# 13  2020                 22729                              NaN
# ...

# %% [markdown]
# **Area, production and farm gate value of marketed vegetables**1
#
# Statistics Canada. Table 32-10-0365-01  Area, production and farm gate value of marketed vegetables
# DOI: https://doi.org/10.25318/3210036501-eng

# %%
df_greenhouse_operations
# Out:
#     Year  Greenhouse_Fruits_Vegetables  Greenhouse_Flowers_Plants
# 0   2007                             0                          0
# 1   2008                           695                       2290
# 2   2009                           695                       2180
# 3   2010                           720                       2055
# 4   2011                           795                       2130
# 5   2012                           815                       2080
# 6   2013                           820                       2035
# 7   2014                           837                       1940
# 8   2015                           861                       1872
# 9   2016                           894                       1811
# 10  2017                           889                       1703
# 11  2018                           866                       1646
# 12  2019                           843                       1620
# ...

# %%
df_agriculture_payments
# Out:
#       Geography  Total direct payments  Total privately funded programs  \
# Years
# 2007     Canada                4089433                           188443
# 2008     Canada                4133110                           316514
# 2009     Canada                3290322                           118033
# 2010     Canada                3138006                           163330
# 2011     Canada                3479924                           166552
# 2012     Canada                3404704                           276071
# 2013     Canada                2685507                           180268
# 2014     Canada                2120698                           263522
# 2015     Canada                2134784                           179227
# 2016     Canada                2442148                           278964
# 2017     Canada                2435937                           112521
# 2018     Canada                2219067                           171233
# ...

# %%
import pandas as pd
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px

# Datos
data = {
    "Years": [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
              2017, 2018, 2019, 2020, 2021, 2022, 2023],
    "Total direct payments": [
        4089433, 4133110, 3290322, 3138006, 3479924, 3404704,
        2685507, 2120698, 2134784, 2442148, 2435937, 2219067,
        3120980, 3459404, 5944084, 7345289, 6586916
    ],
    "Total privately funded programs": [
        188443, 316514, 118033, 163330, 166552, 276071,
        180268, 263522, 179227, 278964, 112521, 171233,
        251886, 200362, 327538, 278119, 179078
    ],
    "Total government funded programs": [
        3900990, 3816596, 3172289, 2974676, 3313372, 3128633,
        2505239, 1857176, 1955557, 2163184, 2323416, 2047834,
        2869094, 3259042, 5616546, 7067170, 6407838
    ],
    "Provincial Stabilization Programs": [
        878184, 655095, 695826, 210239, 459094, 504273,
        335321, 196538, 129771, 329567, 222995, 320967,
        268730, 408488, 168630, 335556, 671329
    ],
    "Crop Insurance": [
        566261, 598208, 810109, 1146642, 1304036, 1215618,
        1069476, 777446, 1107471, 1045184, 1226408, 893000,
        1408521, 1704119, 3749378, 4897368, 3881612
    ],
    "Livestock Insurance Programs": [
        110, 103, 50, 167, 877, 14009,
        13095, 2306, 5816, 32271, 3685, 10157,
        57765, 122148, 1859, 7684, 848
    ],
    "AgriInvest": [
        None, 305664, 357814, 328340, 424867, 452286,
        418620, 320989, 268853, 297341, 281386, 289132,
        261742, 261982, 258588, 265793, 314920
    ],
    "AgriStability": [
        43460, 592378, 789703, 833880, 740841, 726059,
        517437, 432894, 295718, 311025, 356462, 339995,
        365519, 452930, 366370, 406411, 396639
    ],
    "AgriRecovery": [
        None, 16034, 19142, 402475, 292904, 49709,
        570, 1289, 4106, 2703, 8965, 16653,
        16779, 17112, 422788, 392828, 47172
    ],
}

# Crear un DataFrame
df = pd.DataFrame(data)

# Inicializar la aplicación Dash
app = dash.Dash(__name__)

# Diseño de la aplicación
app.layout = html.Div([
    html.H1("Programas Agrícolas en Canadá", style={'textAlign': 'center'}),

    dcc.Dropdown(
        id='variable-dropdown',
        options=[
            {'label': 'Total direct payments', 'value': 'Total direct payments'},
            {'label': 'Total privately funded programs', 'value': 'Total privately funded programs'},
            {'label': 'Total government funded programs', 'value': 'Total government funded programs'},
            {'label': 'Provincial Stabilization Programs', 'value': 'Provincial Stabilization Programs'},
            {'label': 'Crop Insurance', 'value': 'Crop Insurance'},
            {'label': 'Livestock Insurance Programs', 'value': 'Livestock Insurance Programs'},
            {'label': 'AgriInvest', 'value': 'AgriInvest'},
            {'label': 'AgriStability', 'value': 'AgriStability'},
            {'label': 'AgriRecovery', 'value': 'AgriRecovery'},
        ],
        value='Total direct payments',  # Valor predeterminado
        clearable=False,
        style={'width': '50%', 'margin': 'auto'}
    ),

    dcc.Graph(id='agriculture-line-graph', style={'margin': 'auto', 'width': '80%', 'height': '400px'})
], style={'textAlign': 'center'})

# Callback para actualizar la gráfica basada en la variable seleccionada
@app.callback(
    Output('agriculture-line-graph', 'figure'),
    Input('variable-dropdown', 'value')
)
def update_graph(selected_variable):
    # Crear un gráfico de líneas
    fig = px.line(df, x='Years', y=selected_variable,
                   title=f'Datos de {selected_variable} en Canadá',
                   labels={'value': selected_variable, 'Years': 'Año'},
                   line_shape='linear', markers=True)

    # Estilo minimalista
    fig.update_layout(
        plot_bgcolor='white',
        xaxis=dict(showgrid=False),
        yaxis=dict(showgrid=False),
        title_font=dict(size=20),
        font=dict(size=14),
    )

    return fig

# Ejecutar la aplicación
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import pandas as pd

# Datos de ejemplo (reemplazar con tus datos)
data_year = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Greenhouse_Fruits_Vegetables': [0, 695, 695, 720, 795, 815, 820, 837, 861, 894, 889, 866, 843, 858, 892, 930, 920],
    'Greenhouse_Flowers_Plants': [0, 2290, 2180, 2055, 2130, 2080, 2035, 1940, 1872, 1811, 1703, 1646, 1620, 1615, 1557, 1545, 1523]
}

data_payments = {
    'Years': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Total direct payments': [4089433, 4133110, 3290322, 3138006, 3479924, 3404704, 2685507, 2120698, 2134784, 2442148, 2435937, 2219067, 3120980, 3459404, 5944084, 7345289, 6586916]
}

# Crear DataFrames
df_year = pd.DataFrame(data_year)
df_payments = pd.DataFrame(data_payments)

# Renombrar la columna para facilitar el merge
df_year.rename(columns={'Year': 'Years'}, inplace=True)

# Unir los DataFrames
df_merged = pd.merge(df_year, df_payments, on='Years', how='inner')

# Mostrar el DataFrame combinado
print(df_merged)

# Opcional: Guardar el DataFrame combinado en un archivo CSV
df_merged.to_csv('merged_agriculture_data.csv', index=False)
# Out:
#     Years  Greenhouse_Fruits_Vegetables  Greenhouse_Flowers_Plants  \
# 0    2007                             0                          0
# 1    2008                           695                       2290
# 2    2009                           695                       2180
# 3    2010                           720                       2055
# 4    2011                           795                       2130
# 5    2012                           815                       2080
# 6    2013                           820                       2035
# 7    2014                           837                       1940
# 8    2015                           861                       1872
# 9    2016                           894                       1811
# 10   2017                           889                       1703
# 11   2018                           866                       1646
# 12   2019                           843                       1620
# ...

# %%
# !pip install pandas seaborn matplotlib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Datos de ejemplo (usa el DataFrame df_merged ya creado)
data_year = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Greenhouse_Fruits_Vegetables': [0, 695, 695, 720, 795, 815, 820, 837, 861, 894, 889, 866, 843, 858, 892, 930, 920],
    'Greenhouse_Flowers_Plants': [0, 2290, 2180, 2055, 2130, 2080, 2035, 1940, 1872, 1811, 1703, 1646, 1620, 1615, 1557, 1545, 1523]
}

data_payments = {
    'Years': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Total direct payments': [4089433, 4133110, 3290322, 3138006, 3479924, 3404704, 2685507, 2120698, 2134784, 2442148, 2435937, 2219067, 3120980, 3459404, 5944084, 7345289, 6586916]
}

# Crear DataFrames
df_year = pd.DataFrame(data_year)
df_payments = pd.DataFrame(data_payments)

# Renombrar la columna para facilitar el merge
df_year.rename(columns={'Year': 'Years'}, inplace=True)

# Unir los DataFrames
df_merged = pd.merge(df_year, df_payments, on='Years', how='inner')

# Análisis de correlación
correlation_matrix = df_merged.corr()

# Mostrar la matriz de correlación
print(correlation_matrix)

# Visualizar la matriz de correlación con un heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Matriz de Correlación')
plt.show()
# Out:
# ...
#                                  Years  Greenhouse_Fruits_Vegetables  \
# Years                         1.000000                      0.658848
# Greenhouse_Fruits_Vegetables  0.658848                      1.000000
# Greenhouse_Flowers_Plants    -0.074993                      0.685029
# Total direct payments         0.432893                      0.037005
#
#                               Greenhouse_Flowers_Plants  Total direct payments
# Years                                         -0.074993               0.432893
# Greenhouse_Fruits_Vegetables                   0.685029               0.037005
# Greenhouse_Flowers_Plants                      1.000000              -0.261154
# Total direct payments                         -0.261154               1.000000
